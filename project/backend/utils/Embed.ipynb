# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device: {device}")
# Out:
# device: cuda

# %%
import os
import glob
import re
import multiprocessing
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

import torch
from sentence_transformers import SentenceTransformer
import chromadb
from langchain_experimental.text_splitter import SemanticChunker

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device: {device}")

emb_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)

class TorchEmbedder:
    def embed_documents(self, docs):
        return emb_model.encode(docs, convert_to_numpy=True).tolist()

embedder = TorchEmbedder()
splitter = SemanticChunker(embedder)

client = chromadb.PersistentClient(path="./embData")
collection = client.get_or_create_collection("movies")


def _sanitize_tag(s):
    return re.sub(r"[^0-9A-Za-z_-]", "_", s)


def process_file(file_path, encode_batch_size=32):
    folder_name = os.path.basename(os.path.dirname(file_path))
    if "_" in folder_name:
        movie_name, imdb_id = folder_name.rsplit("_", 1)
    else:
        movie_name, imdb_id = folder_name, "unknown"

    character = os.path.splitext(os.path.basename(file_path))[0]

    with open(file_path, "r", encoding="utf-8") as f:
        raw_text = f.read()

    # semantic chunking
    chunks = splitter.create_documents([raw_text])

    ids, texts, metadatas = [], [], []
    for i, chunk in enumerate(chunks):
        chunk_id = f"{_sanitize_tag(folder_name)}__{_sanitize_tag(character)}__{i}"
        ids.append(chunk_id)
        texts.append(chunk.page_content)
        metadatas.append({
            "imdb_id": imdb_id,
            "movie": movie_name,
            "character": character,
            "filename": os.path.basename(file_path),
            "chunk_index": i
        })

    # embeddings
    embeddings = []
    for i in range(0, len(texts), encode_batch_size):
        sub_texts = texts[i:i + encode_batch_size]
        embs = emb_model.encode(sub_texts, show_progress_bar=False, convert_to_numpy=True)
        embeddings.extend(embs.tolist())

    return ids, texts, embeddings, metadatas


def process_all(parent_path, encode_batch_size=32, workers=None, batch_size=500):
    files = sorted(glob.glob(os.path.join(parent_path, "*", "*.txt")))
    print(f"Found {len(files)} files to process.")

    if workers is None:
        workers = min(32, multiprocessing.cpu_count())

    results_buffer = {"ids": [], "docs": [], "embs": [], "metas": []}

    with ThreadPoolExecutor(max_workers=workers) as executor:
        futures = [executor.submit(process_file, file, encode_batch_size) for file in files]

        with tqdm(total=len(futures), desc="Processing Files", unit="file") as pbar:
            for f in as_completed(futures):
                try:
                    ids, texts, embeddings, metadatas = f.result()

                    results_buffer["ids"].extend(ids)
                    results_buffer["docs"].extend(texts)
                    results_buffer["embs"].extend(embeddings)
                    results_buffer["metas"].extend(metadatas)

                    if len(results_buffer["ids"]) >= batch_size:
                        collection.add(
                            ids=results_buffer["ids"],
                            documents=results_buffer["docs"],
                            embeddings=results_buffer["embs"],
                            metadatas=results_buffer["metas"]
                        )
                        results_buffer = {"ids": [], "docs": [], "embs": [], "metas": []}

                except Exception as e:
                    print("Error:", e)
                finally:
                    pbar.update(1)

    if results_buffer["ids"]:
        collection.add(
            ids=results_buffer["ids"],
            documents=results_buffer["docs"],
            embeddings=results_buffer["embs"],
            metadatas=results_buffer["metas"]
        )

    print("✅ Completed embedding + storage.")


if __name__ == "__main__":
    parent = r"C:\Users\anura\Desktop\NPN Hackathon\movie_characters\data\movie_character_texts\movie_character_texts"
    process_all(parent, encode_batch_size=256, workers=None, batch_size=1000)

# %%
# !pip install langchain_experimental
# Out:
# Requirement already satisfied: langchain_experimental in c:\users\anura\anaconda3\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\anura\anaconda3\lib\site-packages (from langchain_experimental) (0.3.17)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in c:\users\anura\anaconda3\lib\site-packages (from langchain_experimental) (0.3.51)
# Requirement already satisfied: langchain<1.0.0,>=0.3.18 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.23)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.29)
# Requirement already satisfied: requests<3,>=2 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.11.16)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.7.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.1.147)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.4.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in c:\users\anura\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anura\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\anura\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\anura\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\anura\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.10.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\anura\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\anura\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\anura\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anura\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\anura\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.18->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anura\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\anura\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anura\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anura\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\anura\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\anura\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anura\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anura\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anura\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anura\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\anura\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.1.1)
# Requirement already satisfied: anyio in c:\users\anura\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\anura\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\anura\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anura\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\anura\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
